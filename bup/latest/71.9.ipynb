# %%
import theano
import sys
import numpy

from framework.Network import Network
from framework.ConvPoolLayer import ConvPoolLayer
from framework.FullyConnectedLayer import FullyConnectedLayer
from framework.SoftmaxLayer import SoftmaxLayer
from framework.DataLoader import load_data

# CONFIG
try: theano.config.device = 'gpu'
except: pass
theano.config.floatX = 'float32'
numpy.random.seed(0)
# Out:
# Using gpu device 0: GeForce GTX 970

# %%
# HYPER PARAMETERS
mini_batch_size = 100
epochs = 400
learning_rate = 0.05
data_split = [0.5, 0.75, 1]

# %%
net = Network([
            ConvPoolLayer(image_shape=(mini_batch_size, 3, 128, 128),
                      filter_shape=(100, 3, 9, 9),
                      poolsize=(3, 3)),
            # output ( 128 - 9 + 1 ) / 3 = 40
            ConvPoolLayer(image_shape=(mini_batch_size, 100, 40, 40),
                      filter_shape=(40, 100, 2, 2),
                      poolsize=(3, 3)),
            # output ( 40 - 2 + 1 ) / 3 = 13
            ConvPoolLayer(image_shape=(mini_batch_size, 40, 13, 13),
                      filter_shape=(10, 40, 2, 2),
                      poolsize=(2, 2)),
            # output ( 13 - 2 + 1 ) / 2 = 6
            FullyConnectedLayer(n_in=10*6*6, n_out=80, p_dropout=0.2),
            SoftmaxLayer(n_in=80, n_out=8, p_dropout=0.2)],
            mini_batch_size)

# %%
training_data, validation_data, test_data = load_data(data_split=data_split)
# Out:
# ... loading data
# [2 7 3 ..., 0 0 2]
# (debug) Number of training images: (4032L, 2L)
# (debug) Number of validation images: (2016L, 2L)
# (debug) Number of test images: (2016L, 2L)

# %%
net.train(training_data, epochs, mini_batch_size, learning_rate,
            validation_data, test_data)
# Out:
# ... starting validation
# ... epoch 0: validation accuracy 12.30%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 12.55%
# ... starting validation
# ... epoch 1: validation accuracy 12.30%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 12.55%
# ... starting validation
# ... epoch 2: validation accuracy 12.75%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 13.00%
# ... starting validation
# ... epoch 3: validation accuracy 19.65%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 17.35%
# ... starting validation
# ... epoch 4: validation accuracy 21.60%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 21.00%
# ... starting validation
# ... epoch 5: validation accuracy 20.00%
# ... starting validation
# ... epoch 6: validation accuracy 25.05%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 23.30%
# ... starting validation
# ... epoch 7: validation accuracy 23.40%
# ... starting validation
# ... epoch 8: validation accuracy 24.85%
# ... starting validation
# ... epoch 9: validation accuracy 25.50%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 24.85%
# ... starting validation
# ... epoch 10: validation accuracy 26.45%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 24.85%
# ... starting validation
# ... epoch 11: validation accuracy 26.50%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 23.15%
# ... starting validation
# ... epoch 12: validation accuracy 27.60%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 26.70%
# ... starting validation
# ... epoch 13: validation accuracy 27.90%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 26.40%
# ... starting validation
# ... epoch 14: validation accuracy 21.00%
# ... starting validation
# ... epoch 15: validation accuracy 27.45%
# ... starting validation
# ... epoch 16: validation accuracy 28.15%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 26.55%
# ... starting validation
# ... epoch 17: validation accuracy 29.70%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 29.70%
# ... starting validation
# ... epoch 18: validation accuracy 28.80%
# ... starting validation
# ... epoch 19: validation accuracy 30.30%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 28.25%
# ... starting validation
# ... epoch 20: validation accuracy 34.05%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 33.95%
# ... starting validation
# ... epoch 21: validation accuracy 35.70%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 33.15%
# ... starting validation
# ... epoch 22: validation accuracy 35.25%
# ... starting validation
# ... epoch 23: validation accuracy 37.65%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 34.30%
# ... starting validation
# ... epoch 24: validation accuracy 36.95%
# ... starting validation
# ... epoch 25: validation accuracy 36.80%
# ... starting validation
# ... epoch 26: validation accuracy 37.95%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 34.40%
# ... starting validation
# ... epoch 27: validation accuracy 38.10%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 36.85%
# ... starting validation
# ... epoch 28: validation accuracy 37.45%
# ... starting validation
# ... epoch 29: validation accuracy 38.20%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 36.20%
# ... starting validation
# ... epoch 30: validation accuracy 38.85%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 37.45%
# ... starting validation
# ... epoch 31: validation accuracy 40.00%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 36.15%
# ... starting validation
# ... epoch 32: validation accuracy 40.05%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 37.50%
# ... starting validation
# ... epoch 33: validation accuracy 39.20%
# ... starting validation
# ... epoch 34: validation accuracy 41.15%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 39.15%
# ... starting validation
# ... epoch 35: validation accuracy 40.55%
# ... starting validation
# ... epoch 36: validation accuracy 42.10%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 39.10%
# ... starting validation
# ... epoch 37: validation accuracy 40.90%
# ... starting validation
# ... epoch 38: validation accuracy 42.20%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 39.60%
# ... starting validation
# ... epoch 39: validation accuracy 39.75%
# ... starting validation
# ... epoch 40: validation accuracy 42.30%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 39.45%
# ... starting validation
# ... epoch 41: validation accuracy 41.85%
# ... starting validation
# ... epoch 42: validation accuracy 43.25%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 41.60%
# ... starting validation
# ... epoch 43: validation accuracy 43.45%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 40.65%
# ... starting validation
# ... epoch 44: validation accuracy 45.05%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 41.60%
# ... starting validation
# ... epoch 45: validation accuracy 43.50%
# ... starting validation
# ... epoch 46: validation accuracy 44.35%
# ... starting validation
# ... epoch 47: validation accuracy 43.25%
# ... starting validation
# ... epoch 48: validation accuracy 45.90%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 42.10%
# ... starting validation
# ... epoch 49: validation accuracy 44.55%
# ... starting validation
# ... epoch 50: validation accuracy 44.60%
# ... starting validation
# ... epoch 51: validation accuracy 43.40%
# ... starting validation
# ... epoch 52: validation accuracy 44.05%
# ... starting validation
# ... epoch 53: validation accuracy 45.00%
# ... starting validation
# ... epoch 54: validation accuracy 46.35%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 42.50%
# ... starting validation
# ... epoch 55: validation accuracy 44.85%
# ... starting validation
# ... epoch 56: validation accuracy 44.45%
# ... starting validation
# ... epoch 57: validation accuracy 43.90%
# ... starting validation
# ... epoch 58: validation accuracy 46.35%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 43.95%
# ... starting validation
# ... epoch 59: validation accuracy 43.65%
# ... starting validation
# ... epoch 60: validation accuracy 46.10%
# ... starting validation
# ... epoch 61: validation accuracy 46.80%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 43.60%
# ... starting validation
# ... epoch 62: validation accuracy 44.20%
# ... starting validation
# ... epoch 63: validation accuracy 47.05%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 44.50%
# ... starting validation
# ... epoch 64: validation accuracy 46.65%
# ... starting validation
# ... epoch 65: validation accuracy 49.10%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 46.00%
# ... starting validation
# ... epoch 66: validation accuracy 47.65%
# ... starting validation
# ... epoch 67: validation accuracy 48.90%
# ... starting validation
# ... epoch 68: validation accuracy 49.15%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 46.40%
# ... starting validation
# ... epoch 69: validation accuracy 46.30%
# ... starting validation
# ... epoch 70: validation accuracy 49.10%
# ... starting validation
# ... epoch 71: validation accuracy 42.60%
# ... starting validation
# ... epoch 72: validation accuracy 47.90%
# ... starting validation
# ... epoch 73: validation accuracy 48.80%
# ... starting validation
# ... epoch 74: validation accuracy 47.45%
# ... starting validation
# ... epoch 75: validation accuracy 50.50%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 47.85%
# ... starting validation
# ... epoch 76: validation accuracy 46.85%
# ... starting validation
# ... epoch 77: validation accuracy 48.65%
# ... starting validation
# ... epoch 78: validation accuracy 50.60%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 47.90%
# ... starting validation
# ... epoch 79: validation accuracy 49.90%
# ... starting validation
# ... epoch 80: validation accuracy 49.85%
# ... starting validation
# ... epoch 81: validation accuracy 51.00%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 48.35%
# ... starting validation
# ... epoch 82: validation accuracy 52.85%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 48.05%
# ... starting validation
# ... epoch 83: validation accuracy 50.30%
# ... starting validation
# ... epoch 84: validation accuracy 48.80%
# ... starting validation
# ... epoch 85: validation accuracy 49.00%
# ... starting validation
# ... epoch 86: validation accuracy 54.75%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 50.35%
# ... starting validation
# ... epoch 87: validation accuracy 50.50%
# ... starting validation
# ... epoch 88: validation accuracy 53.60%
# ... starting validation
# ... epoch 89: validation accuracy 52.90%
# ... starting validation
# ... epoch 90: validation accuracy 51.70%
# ... starting validation
# ... epoch 91: validation accuracy 52.85%
# ... starting validation
# ... epoch 92: validation accuracy 55.05%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 52.20%
# ... starting validation
# ... epoch 93: validation accuracy 52.35%
# ... starting validation
# ... epoch 94: validation accuracy 52.70%
# ... starting validation
# ... epoch 95: validation accuracy 56.25%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 52.15%
# ... starting validation
# ... epoch 96: validation accuracy 54.90%
# ... starting validation
# ... epoch 97: validation accuracy 52.00%
# ... starting validation
# ... epoch 98: validation accuracy 54.50%
# ... starting validation
# ... epoch 99: validation accuracy 54.30%
# ... starting validation
# ... epoch 100: validation accuracy 51.25%
# ... starting validation
# ... epoch 101: validation accuracy 54.15%
# ... starting validation
# ... epoch 102: validation accuracy 55.55%
# ... starting validation
# ... epoch 103: validation accuracy 54.10%
# ... starting validation
# ... epoch 104: validation accuracy 53.35%
# ... starting validation
# ... epoch 105: validation accuracy 55.75%
# ... starting validation
# ... epoch 106: validation accuracy 53.85%
# ... starting validation
# ... epoch 107: validation accuracy 51.95%
# ... starting validation
# ... epoch 108: validation accuracy 54.25%
# ... starting validation
# ... epoch 109: validation accuracy 57.20%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 53.10%
# ... starting validation
# ... epoch 110: validation accuracy 55.35%
# ... starting validation
# ... epoch 111: validation accuracy 57.75%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 55.30%
# ... starting validation
# ... epoch 112: validation accuracy 56.10%
# ... starting validation
# ... epoch 113: validation accuracy 58.65%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 55.85%
# ... starting validation
# ... epoch 114: validation accuracy 55.85%
# ... starting validation
# ... epoch 115: validation accuracy 58.20%
# ... starting validation
# ... epoch 116: validation accuracy 56.00%
# ... starting validation
# ... epoch 117: validation accuracy 57.20%
# ... starting validation
# ... epoch 118: validation accuracy 58.25%
# ... starting validation
# ... epoch 119: validation accuracy 55.85%
# ... starting validation
# ... epoch 120: validation accuracy 57.50%
# ... starting validation
# ... epoch 121: validation accuracy 55.45%
# ... starting validation
# ... epoch 122: validation accuracy 56.25%
# ... starting validation
# ... epoch 123: validation accuracy 57.10%
# ... starting validation
# ... epoch 124: validation accuracy 56.75%
# ... starting validation
# ... epoch 125: validation accuracy 57.20%
# ... starting validation
# ... epoch 126: validation accuracy 53.20%
# ... starting validation
# ... epoch 127: validation accuracy 57.10%
# ... starting validation
# ... epoch 128: validation accuracy 58.60%
# ... starting validation
# ... epoch 129: validation accuracy 58.35%
# ... starting validation
# ... epoch 130: validation accuracy 57.25%
# ... starting validation
# ... epoch 131: validation accuracy 58.55%
# ... starting validation
# ... epoch 132: validation accuracy 57.65%
# ... starting validation
# ... epoch 133: validation accuracy 58.70%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 55.85%
# ... starting validation
# ... epoch 134: validation accuracy 58.55%
# ... starting validation
# ... epoch 135: validation accuracy 59.40%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 56.50%
# ... starting validation
# ... epoch 136: validation accuracy 58.10%
# ... starting validation
# ... epoch 137: validation accuracy 60.30%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 57.50%
# ... starting validation
# ... epoch 138: validation accuracy 58.50%
# ... starting validation
# ... epoch 139: validation accuracy 60.15%
# ... starting validation
# ... epoch 140: validation accuracy 60.25%
# ... starting validation
# ... epoch 141: validation accuracy 60.35%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 56.70%
# ... starting validation
# ... epoch 142: validation accuracy 57.35%
# ... starting validation
# ... epoch 143: validation accuracy 57.05%
# ... starting validation
# ... epoch 144: validation accuracy 56.95%
# ... starting validation
# ... epoch 145: validation accuracy 54.80%
# ... starting validation
# ... epoch 146: validation accuracy 60.30%
# ... starting validation
# ... epoch 147: validation accuracy 57.40%
# ... starting validation
# ... epoch 148: validation accuracy 60.65%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 56.05%
# ... starting validation
# ... epoch 149: validation accuracy 59.60%
# ... starting validation
# ... epoch 150: validation accuracy 58.50%
# ... starting validation
# ... epoch 151: validation accuracy 59.15%
# ... starting validation
# ... epoch 152: validation accuracy 57.95%
# ... starting validation
# ... epoch 153: validation accuracy 60.85%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 57.30%
# ... starting validation
# ... epoch 154: validation accuracy 59.55%
# ... starting validation
# ... epoch 155: validation accuracy 60.50%
# ... starting validation
# ... epoch 156: validation accuracy 60.95%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 57.20%
# ... starting validation
# ... epoch 157: validation accuracy 61.30%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 56.25%
# ... starting validation
# ... epoch 158: validation accuracy 58.70%
# ... starting validation
# ... epoch 159: validation accuracy 57.90%
# ... starting validation
# ... epoch 160: validation accuracy 59.75%
# ... starting validation
# ... epoch 161: validation accuracy 58.50%
# ... starting validation
# ... epoch 162: validation accuracy 61.45%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 57.50%
# ... starting validation
# ... epoch 163: validation accuracy 58.20%
# ... starting validation
# ... epoch 164: validation accuracy 58.90%
# ... starting validation
# ... epoch 165: validation accuracy 60.20%
# ... starting validation
# ... epoch 166: validation accuracy 61.35%
# ... starting validation
# ... epoch 167: validation accuracy 59.55%
# ... starting validation
# ... epoch 168: validation accuracy 59.00%
# ... starting validation
# ... epoch 169: validation accuracy 62.90%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 59.45%
# ... starting validation
# ... epoch 170: validation accuracy 60.40%
# ... starting validation
# ... epoch 171: validation accuracy 61.75%
# ... starting validation
# ... epoch 172: validation accuracy 61.75%
# ... starting validation
# ... epoch 173: validation accuracy 58.20%
# ... starting validation
# ... epoch 174: validation accuracy 63.30%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 59.55%
# ... starting validation
# ... epoch 175: validation accuracy 63.15%
# ... starting validation
# ... epoch 176: validation accuracy 60.80%
# ... starting validation
# ... epoch 177: validation accuracy 62.50%
# ... starting validation
# ... epoch 178: validation accuracy 61.50%
# ... starting validation
# ... epoch 179: validation accuracy 59.50%
# ... starting validation
# ... epoch 180: validation accuracy 63.65%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 59.50%
# ... starting validation
# ... epoch 181: validation accuracy 62.70%
# ... starting validation
# ... epoch 182: validation accuracy 63.35%
# ... starting validation
# ... epoch 183: validation accuracy 60.85%
# ... starting validation
# ... epoch 184: validation accuracy 60.80%
# ... starting validation
# ... epoch 185: validation accuracy 63.25%
# ... starting validation
# ... epoch 186: validation accuracy 60.05%
# ... starting validation
# ... epoch 187: validation accuracy 62.45%
# ... starting validation
# ... epoch 188: validation accuracy 64.00%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 58.55%
# ... starting validation
# ... epoch 189: validation accuracy 62.20%
# ... starting validation
# ... epoch 190: validation accuracy 62.35%
# ... starting validation
# ... epoch 191: validation accuracy 63.05%
# ... starting validation
# ... epoch 192: validation accuracy 63.65%
# ... starting validation
# ... epoch 193: validation accuracy 61.50%
# ... starting validation
# ... epoch 194: validation accuracy 59.40%
# ... starting validation
# ... epoch 195: validation accuracy 63.60%
# ... starting validation
# ... epoch 196: validation accuracy 62.25%
# ... starting validation
# ... epoch 197: validation accuracy 63.50%
# ... starting validation
# ... epoch 198: validation accuracy 62.05%
# ... starting validation
# ... epoch 199: validation accuracy 61.60%
# ... starting validation
# ... epoch 200: validation accuracy 66.10%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 61.25%
# ... starting validation
# ... epoch 201: validation accuracy 61.00%
# ... starting validation
# ... epoch 202: validation accuracy 64.90%
# ... starting validation
# ... epoch 203: validation accuracy 64.70%
# ... starting validation
# ... epoch 204: validation accuracy 61.85%
# ... starting validation
# ... epoch 205: validation accuracy 63.90%
# ... starting validation
# ... epoch 206: validation accuracy 62.65%
# ... starting validation
# ... epoch 207: validation accuracy 64.15%
# ... starting validation
# ... epoch 208: validation accuracy 64.35%
# ... starting validation
# ... epoch 209: validation accuracy 65.60%
# ... starting validation
# ... epoch 210: validation accuracy 63.10%
# ... starting validation
# ... epoch 211: validation accuracy 63.35%
# ... starting validation
# ... epoch 212: validation accuracy 64.90%
# ... starting validation
# ... epoch 213: validation accuracy 63.60%
# ... starting validation
# ... epoch 214: validation accuracy 60.60%
# ... starting validation
# ... epoch 215: validation accuracy 61.55%
# ... starting validation
# ... epoch 216: validation accuracy 63.75%
# ... starting validation
# ... epoch 217: validation accuracy 61.30%
# ... starting validation
# ... epoch 218: validation accuracy 63.30%
# ... starting validation
# ... epoch 219: validation accuracy 63.25%
# ... starting validation
# ... epoch 220: validation accuracy 63.30%
# ... starting validation
# ... epoch 221: validation accuracy 65.65%
# ... starting validation
# ... epoch 222: validation accuracy 65.50%
# ... starting validation
# ... epoch 223: validation accuracy 66.45%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 61.60%
# ... starting validation
# ... epoch 224: validation accuracy 61.50%
# ... starting validation
# ... epoch 225: validation accuracy 66.10%
# ... starting validation
# ... epoch 226: validation accuracy 64.75%
# ... starting validation
# ... epoch 227: validation accuracy 63.70%
# ... starting validation
# ... epoch 228: validation accuracy 65.30%
# ... starting validation
# ... epoch 229: validation accuracy 64.70%
# ... starting validation
# ... epoch 230: validation accuracy 65.75%
# ... starting validation
# ... epoch 231: validation accuracy 65.90%
# ... starting validation
# ... epoch 232: validation accuracy 66.10%
# ... starting validation
# ... epoch 233: validation accuracy 62.70%
# ... starting validation
# ... epoch 234: validation accuracy 63.95%
# ... starting validation
# ... epoch 235: validation accuracy 66.95%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 62.40%
# ... starting validation
# ... epoch 236: validation accuracy 64.60%
# ... starting validation
# ... epoch 237: validation accuracy 66.05%
# ... starting validation
# ... epoch 238: validation accuracy 64.50%
# ... starting validation
# ... epoch 239: validation accuracy 64.45%
# ... starting validation
# ... epoch 240: validation accuracy 64.75%
# ... starting validation
# ... epoch 241: validation accuracy 64.20%
# ... starting validation
# ... epoch 242: validation accuracy 65.35%
# ... starting validation
# ... epoch 243: validation accuracy 66.20%
# ... starting validation
# ... epoch 244: validation accuracy 66.10%
# ... starting validation
# ... epoch 245: validation accuracy 64.50%
# ... starting validation
# ... epoch 246: validation accuracy 65.50%
# ... starting validation
# ... epoch 247: validation accuracy 66.95%
# ... starting validation
# ... epoch 248: validation accuracy 66.75%
# ... starting validation
# ... epoch 249: validation accuracy 63.85%
# ... starting validation
# ... epoch 250: validation accuracy 65.55%
# ... starting validation
# ... epoch 251: validation accuracy 65.60%
# ... starting validation
# ... epoch 252: validation accuracy 66.80%
# ... starting validation
# ... epoch 253: validation accuracy 63.05%
# ... starting validation
# ... epoch 254: validation accuracy 64.80%
# ... starting validation
# ... epoch 255: validation accuracy 68.05%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 63.80%
# ... starting validation
# ... epoch 256: validation accuracy 68.10%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 62.60%
# ... starting validation
# ... epoch 257: validation accuracy 64.30%
# ... starting validation
# ... epoch 258: validation accuracy 65.60%
# ... starting validation
# ... epoch 259: validation accuracy 67.55%
# ... starting validation
# ... epoch 260: validation accuracy 66.30%
# ... starting validation
# ... epoch 261: validation accuracy 66.25%
# ... starting validation
# ... epoch 262: validation accuracy 64.85%
# ... starting validation
# ... epoch 263: validation accuracy 63.50%
# ... starting validation
# ... epoch 264: validation accuracy 69.15%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 63.55%
# ... starting validation
# ... epoch 265: validation accuracy 64.60%
# ... starting validation
# ... epoch 266: validation accuracy 67.00%
# ... starting validation
# ... epoch 267: validation accuracy 67.85%
# ... starting validation
# ... epoch 268: validation accuracy 65.15%
# ... starting validation
# ... epoch 269: validation accuracy 68.15%
# ... starting validation
# ... epoch 270: validation accuracy 62.60%
# ... starting validation
# ... epoch 271: validation accuracy 65.15%
# ... starting validation
# ... epoch 272: validation accuracy 68.20%
# ... starting validation
# ... epoch 273: validation accuracy 67.70%
# ... starting validation
# ... epoch 274: validation accuracy 63.70%
# ... starting validation
# ... epoch 275: validation accuracy 64.80%
# ... starting validation
# ... epoch 276: validation accuracy 64.90%
# ... starting validation
# ... epoch 277: validation accuracy 66.20%
# ... starting validation
# ... epoch 278: validation accuracy 63.80%
# ... starting validation
# ... epoch 279: validation accuracy 63.50%
# ... starting validation
# ... epoch 280: validation accuracy 62.40%
# ... starting validation
# ... epoch 281: validation accuracy 68.20%
# ... starting validation
# ... epoch 282: validation accuracy 69.20%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 63.85%
# ... starting validation
# ... epoch 283: validation accuracy 65.75%
# ... starting validation
# ... epoch 284: validation accuracy 65.40%
# ... starting validation
# ... epoch 285: validation accuracy 67.20%
# ... starting validation
# ... epoch 286: validation accuracy 64.70%
# ... starting validation
# ... epoch 287: validation accuracy 67.75%
# ... starting validation
# ... epoch 288: validation accuracy 66.20%
# ... starting validation
# ... epoch 289: validation accuracy 65.35%
# ... starting validation
# ... epoch 290: validation accuracy 67.75%
# ... starting validation
# ... epoch 291: validation accuracy 67.15%
# ... starting validation
# ... epoch 292: validation accuracy 63.80%
# ... starting validation
# ... epoch 293: validation accuracy 68.65%
# ... starting validation
# ... epoch 294: validation accuracy 67.90%
# ... starting validation
# ... epoch 295: validation accuracy 64.95%
# ... starting validation
# ... epoch 296: validation accuracy 68.30%
# ... starting validation
# ... epoch 297: validation accuracy 68.55%
# ... starting validation
# ... epoch 298: validation accuracy 67.55%
# ... starting validation
# ... epoch 299: validation accuracy 66.35%
# ... starting validation
# ... epoch 300: validation accuracy 68.15%
# ... starting validation
# ... epoch 301: validation accuracy 67.70%
# ... starting validation
# ... epoch 302: validation accuracy 68.95%
# ... starting validation
# ... epoch 303: validation accuracy 67.95%
# ... starting validation
# ... epoch 304: validation accuracy 67.20%
# ... starting validation
# ... epoch 305: validation accuracy 64.95%
# ... starting validation
# ... epoch 306: validation accuracy 69.15%
# ... starting validation
# ... epoch 307: validation accuracy 66.90%
# ... starting validation
# ... epoch 308: validation accuracy 69.05%
# ... starting validation
# ... epoch 309: validation accuracy 64.15%
# ... starting validation
# ... epoch 310: validation accuracy 63.60%
# ... starting validation
# ... epoch 311: validation accuracy 66.80%
# ... starting validation
# ... epoch 312: validation accuracy 62.95%
# ... starting validation
# ... epoch 313: validation accuracy 67.20%
# ... starting validation
# ... epoch 314: validation accuracy 68.25%
# ... starting validation
# ... epoch 315: validation accuracy 65.50%
# ... starting validation
# ... epoch 316: validation accuracy 67.50%
# ... starting validation
# ... epoch 317: validation accuracy 67.20%
# ... starting validation
# ... epoch 318: validation accuracy 68.10%
# ... starting validation
# ... epoch 319: validation accuracy 69.15%
# ... starting validation
# ... epoch 320: validation accuracy 67.50%
# ... starting validation
# ... epoch 321: validation accuracy 68.90%
# ... starting validation
# ... epoch 322: validation accuracy 67.70%
# ... starting validation
# ... epoch 323: validation accuracy 69.20%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 65.00%
# ... starting validation
# ... epoch 324: validation accuracy 68.45%
# ... starting validation
# ... epoch 325: validation accuracy 69.50%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 64.10%
# ... starting validation
# ... epoch 326: validation accuracy 62.25%
# ... starting validation
# ... epoch 327: validation accuracy 69.15%
# ... starting validation
# ... epoch 328: validation accuracy 67.05%
# ... starting validation
# ... epoch 329: validation accuracy 67.90%
# ... starting validation
# ... epoch 330: validation accuracy 68.15%
# ... starting validation
# ... epoch 331: validation accuracy 68.55%
# ... starting validation
# ... epoch 332: validation accuracy 66.50%
# ... starting validation
# ... epoch 333: validation accuracy 65.95%
# ... starting validation
# ... epoch 334: validation accuracy 70.15%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 65.15%
# ... starting validation
# ... epoch 335: validation accuracy 69.45%
# ... starting validation
# ... epoch 336: validation accuracy 69.15%
# ... starting validation
# ... epoch 337: validation accuracy 66.80%
# ... starting validation
# ... epoch 338: validation accuracy 69.05%
# ... starting validation
# ... epoch 339: validation accuracy 66.25%
# ... starting validation
# ... epoch 340: validation accuracy 66.50%
# ... starting validation
# ... epoch 341: validation accuracy 64.95%
# ... starting validation
# ... epoch 342: validation accuracy 69.20%
# ... starting validation
# ... epoch 343: validation accuracy 68.45%
# ... starting validation
# ... epoch 344: validation accuracy 68.75%
# ... starting validation
# ... epoch 345: validation accuracy 70.35%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 67.10%
# ... starting validation
# ... epoch 346: validation accuracy 68.80%
# ... starting validation
# ... epoch 347: validation accuracy 67.05%
# ... starting validation
# ... epoch 348: validation accuracy 68.70%
# ... starting validation
# ... epoch 349: validation accuracy 67.15%
# ... starting validation
# ... epoch 350: validation accuracy 67.05%
# ... starting validation
# ... epoch 351: validation accuracy 70.25%
# ... starting validation
# ... epoch 352: validation accuracy 68.45%
# ... starting validation
# ... epoch 353: validation accuracy 71.00%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 65.65%
# ... starting validation
# ... epoch 354: validation accuracy 65.85%
# ... starting validation
# ... epoch 355: validation accuracy 70.55%
# ... starting validation
# ... epoch 356: validation accuracy 69.35%
# ... starting validation
# ... epoch 357: validation accuracy 69.35%
# ... starting validation
# ... epoch 358: validation accuracy 68.40%
# ... starting validation
# ... epoch 359: validation accuracy 69.30%
# ... starting validation
# ... epoch 360: validation accuracy 69.85%
# ... starting validation
# ... epoch 361: validation accuracy 66.80%
# ... starting validation
# ... epoch 362: validation accuracy 69.40%
# ... starting validation
# ... epoch 363: validation accuracy 68.55%
# ... starting validation
# ... epoch 364: validation accuracy 68.15%
# ... starting validation
# ... epoch 365: validation accuracy 69.70%
# ... starting validation
# ... epoch 366: validation accuracy 67.45%
# ... starting validation
# ... epoch 367: validation accuracy 70.30%
# ... starting validation
# ... epoch 368: validation accuracy 70.25%
# ... starting validation
# ... epoch 369: validation accuracy 69.85%
# ... starting validation
# ... epoch 370: validation accuracy 70.50%
# ... starting validation
# ... epoch 371: validation accuracy 68.65%
# ... starting validation
# ... epoch 372: validation accuracy 67.80%
# ... starting validation
# ... epoch 373: validation accuracy 66.85%
# ... starting validation
# ... epoch 374: validation accuracy 70.15%
# ... starting validation
# ... epoch 375: validation accuracy 70.30%
# ... starting validation
# ... epoch 376: validation accuracy 68.60%
# ... starting validation
# ... epoch 377: validation accuracy 70.10%
# ... starting validation
# ... epoch 378: validation accuracy 69.15%
# ... starting validation
# ... epoch 379: validation accuracy 69.15%
# ... starting validation
# ... epoch 380: validation accuracy 68.05%
# ... starting validation
# ... epoch 381: validation accuracy 69.30%
# ... starting validation
# ... epoch 382: validation accuracy 68.70%
# ... starting validation
# ... epoch 383: validation accuracy 71.90%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 67.90%
# ... starting validation
# ... epoch 384: validation accuracy 69.90%
# ... starting validation
# ... epoch 385: validation accuracy 70.05%
# ... starting validation
# ... epoch 386: validation accuracy 69.15%
# ... starting validation
# ... epoch 387: validation accuracy 69.20%
# ... starting validation
# ... epoch 388: validation accuracy 69.45%
# ... starting validation
# ... epoch 389: validation accuracy 67.20%
# ... starting validation
# ... epoch 390: validation accuracy 69.35%
# ... starting validation
# ... epoch 391: validation accuracy 69.20%
# ... starting validation
# ... epoch 392: validation accuracy 70.15%
# ... starting validation
# ... epoch 393: validation accuracy 71.60%
# ... starting validation
# ... epoch 394: validation accuracy 69.20%
# ... starting validation
# ... epoch 395: validation accuracy 67.55%
# ... starting validation
# ... epoch 396: validation accuracy 69.90%
# ... starting validation
# ... epoch 397: validation accuracy 68.75%
# ... starting validation
# ... epoch 398: validation accuracy 67.35%
# ... starting validation
# ... epoch 399: validation accuracy 71.00%
# ... finished training network.
# ... best validation accuracy of 71.90% obtained at iteration 15359
# ... corresponding test accuracy of 67.90%
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/iveli/AppData/Local/Theano/compiledir_Windows-8-6.2.9200-Intel64_Family_6_Model_60_Stepping_3_GenuineIntel-2.7.10-64/tmpiaolhk/b18c4391e59fc4031a63b707f1c83fb4.lib and object C:/Users/iveli/AppData/Local/Theano/compiledir_Windows-8-6.2.9200-Intel64_Family_6_Model_60_Stepping_3_GenuineIntel-2.7.10-64/tmpiaolhk/b18c4391e59fc4031a63b707f1c83fb4.exp

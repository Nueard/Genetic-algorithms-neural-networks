# %%
import theano
import sys
import numpy

from framework.Network import Network
from framework.ConvPoolLayer import ConvPoolLayer
from framework.FullyConnectedLayer import FullyConnectedLayer
from framework.SoftmaxLayer import SoftmaxLayer
from framework.DataLoader import load_data

# CONFIG
try: theano.config.device = 'gpu'
except: pass
theano.config.floatX = 'float32'
numpy.random.seed(0)
# Out:
# Using gpu device 0: GeForce GTX 970

# %%
# HYPER PARAMETERS
mini_batch_size = 10
epochs = 400
learning_rate = 0.05
data_split = [0.5, 0.75, 1]

# %%
net = Network([
            ConvPoolLayer(image_shape=(mini_batch_size, 3, 128, 128),
                      filter_shape=(100, 3, 9, 9),
                      poolsize=(3, 3)),
            # output ( 128 - 9 + 1 ) / 3 = 40
            ConvPoolLayer(image_shape=(mini_batch_size, 100, 40, 40),
                      filter_shape=(50, 100, 2, 2),
                      poolsize=(3, 3)),
            # output ( 40 - 2 + 1 ) / 3 = 13
            ConvPoolLayer(image_shape=(mini_batch_size, 50, 13, 13),
                      filter_shape=(15, 50, 2, 2),
                      poolsize=(2, 2)),
            # output ( 13 - 2 + 1 ) / 2 = 6
            FullyConnectedLayer(n_in=15*6*6, n_out=80, p_dropout=0.2),
            SoftmaxLayer(n_in=80, n_out=8, p_dropout=0.2)],
            mini_batch_size)

# %%
training_data, validation_data, test_data = load_data(data_split=data_split)
# Out:
# ... loading data
# (debug) Number of training images: (4032L, 2L)
# (debug) Number of validation images: (2016L, 2L)
# (debug) Number of test images: (2016L, 2L)

# %%
net.train(training_data, epochs, mini_batch_size, learning_rate,
            validation_data, test_data)
# Out:
# ... starting validation
# ... epoch 0: validation accuracy 19.15%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 19.05%
# ... starting validation
# ... epoch 1: validation accuracy 20.45%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 21.14%
# ... starting validation
# ... epoch 2: validation accuracy 22.39%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 23.88%
# ... starting validation
# ... epoch 3: validation accuracy 24.33%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 25.87%
# ... starting validation
# ... epoch 4: validation accuracy 22.79%
# ... starting validation
# ... epoch 5: validation accuracy 20.65%
# ... starting validation
# ... epoch 6: validation accuracy 17.91%
# ... starting validation
# ... epoch 7: validation accuracy 17.76%
# ... starting validation
# ... epoch 8: validation accuracy 37.66%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 36.57%
# ... starting validation
# ... epoch 9: validation accuracy 28.66%
# ... starting validation
# ... epoch 10: validation accuracy 36.67%
# ... starting validation
# ... epoch 11: validation accuracy 37.06%
# ... starting validation
# ... epoch 12: validation accuracy 37.46%
# ... starting validation
# ... epoch 13: validation accuracy 30.80%
# ... starting validation
# ... epoch 14: validation accuracy 40.00%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 39.95%
# ... starting validation
# ... epoch 15: validation accuracy 37.51%
# ... starting validation
# ... epoch 16: validation accuracy 40.45%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 40.75%
# ... starting validation
# ... epoch 17: validation accuracy 40.45%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 42.59%
# ... starting validation
# ... epoch 18: validation accuracy 40.95%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 40.75%
# ... starting validation
# ... epoch 19: validation accuracy 39.65%
# ... starting validation
# ... epoch 20: validation accuracy 38.36%
# ... starting validation
# ... epoch 21: validation accuracy 40.55%
# ... starting validation
# ... epoch 22: validation accuracy 41.09%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 41.99%
# ... starting validation
# ... epoch 23: validation accuracy 38.06%
# ... starting validation
# ... epoch 24: validation accuracy 42.64%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 42.44%
# ... starting validation
# ... epoch 25: validation accuracy 42.64%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 43.83%
# ... starting validation
# ... epoch 26: validation accuracy 40.10%
# ... starting validation
# ... epoch 27: validation accuracy 41.54%
# ... starting validation
# ... epoch 28: validation accuracy 44.18%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 45.02%
# ... starting validation
# ... epoch 29: validation accuracy 40.85%
# ... starting validation
# ... epoch 30: validation accuracy 45.22%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 44.78%
# ... starting validation
# ... epoch 31: validation accuracy 43.73%
# ... starting validation
# ... epoch 32: validation accuracy 41.69%
# ... starting validation
# ... epoch 33: validation accuracy 42.69%
# ... starting validation
# ... epoch 34: validation accuracy 43.48%
# ... starting validation
# ... epoch 35: validation accuracy 45.22%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 45.42%
# ... starting validation
# ... epoch 36: validation accuracy 45.02%
# ... starting validation
# ... epoch 37: validation accuracy 44.33%
# ... starting validation
# ... epoch 38: validation accuracy 46.22%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 45.72%
# ... starting validation
# ... epoch 39: validation accuracy 46.62%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 47.06%
# ... starting validation
# ... epoch 40: validation accuracy 46.82%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 47.61%
# ... starting validation
# ... epoch 41: validation accuracy 47.56%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 47.51%
# ... starting validation
# ... epoch 42: validation accuracy 46.37%
# ... starting validation
# ... epoch 43: validation accuracy 46.42%
# ... starting validation
# ... epoch 44: validation accuracy 46.62%
# ... starting validation
# ... epoch 45: validation accuracy 46.67%
# ... starting validation
# ... epoch 46: validation accuracy 46.47%
# ... starting validation
# ... epoch 47: validation accuracy 48.01%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 46.67%
# ... starting validation
# ... epoch 48: validation accuracy 48.66%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 47.96%
# ... starting validation
# ... epoch 49: validation accuracy 47.96%
# ... starting validation
# ... epoch 50: validation accuracy 47.26%
# ... starting validation
# ... epoch 51: validation accuracy 49.15%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 48.71%
# ... starting validation
# ... epoch 52: validation accuracy 48.31%
# ... starting validation
# ... epoch 53: validation accuracy 50.60%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 50.00%
# ... starting validation
# ... epoch 54: validation accuracy 49.20%
# ... starting validation
# ... epoch 55: validation accuracy 50.85%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 49.60%
# ... starting validation
# ... epoch 56: validation accuracy 50.55%
# ... starting validation
# ... epoch 57: validation accuracy 51.49%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 49.65%
# ... starting validation
# ... epoch 58: validation accuracy 48.91%
# ... starting validation
# ... epoch 59: validation accuracy 49.80%
# ... starting validation
# ... epoch 60: validation accuracy 48.76%
# ... starting validation
# ... epoch 61: validation accuracy 49.65%
# ... starting validation
# ... epoch 62: validation accuracy 49.05%
# ... starting validation
# ... epoch 63: validation accuracy 51.00%
# ... starting validation
# ... epoch 64: validation accuracy 50.95%
# ... starting validation
# ... epoch 65: validation accuracy 50.80%
# ... starting validation
# ... epoch 66: validation accuracy 50.10%
# ... starting validation
# ... epoch 67: validation accuracy 49.90%
# ... starting validation
# ... epoch 68: validation accuracy 44.58%
# ... starting validation
# ... epoch 69: validation accuracy 51.74%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 51.39%
# ... starting validation
# ... epoch 70: validation accuracy 48.01%
# ... starting validation
# ... epoch 71: validation accuracy 51.04%
# ... starting validation
# ... epoch 72: validation accuracy 49.15%
# ... starting validation
# ... epoch 73: validation accuracy 47.66%
# ... starting validation
# ... epoch 74: validation accuracy 51.54%
# ... starting validation
# ... epoch 75: validation accuracy 50.80%
# ... starting validation
# ... epoch 76: validation accuracy 52.74%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 51.14%
# ... starting validation
# ... epoch 77: validation accuracy 50.60%
# ... starting validation
# ... epoch 78: validation accuracy 50.00%
# ... starting validation
# ... epoch 79: validation accuracy 52.79%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 51.49%
# ... starting validation
# ... epoch 80: validation accuracy 50.90%
# ... starting validation
# ... epoch 81: validation accuracy 44.48%
# ... starting validation
# ... epoch 82: validation accuracy 50.90%
# ... starting validation
# ... epoch 83: validation accuracy 51.79%
# ... starting validation
# ... epoch 84: validation accuracy 53.33%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 52.49%
# ... starting validation
# ... epoch 85: validation accuracy 52.19%
# ... starting validation
# ... epoch 86: validation accuracy 53.23%
# ... starting validation
# ... epoch 87: validation accuracy 55.02%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 53.58%
# ... starting validation
# ... epoch 88: validation accuracy 52.94%
# ... starting validation
# ... epoch 89: validation accuracy 51.74%
# ... starting validation
# ... epoch 90: validation accuracy 52.44%
# ... starting validation
# ... epoch 91: validation accuracy 49.20%
# ... starting validation
# ... epoch 92: validation accuracy 50.70%
# ... starting validation
# ... epoch 93: validation accuracy 54.13%
# ... starting validation
# ... epoch 94: validation accuracy 54.08%
# ... starting validation
# ... epoch 95: validation accuracy 51.99%
# ... starting validation
# ... epoch 96: validation accuracy 51.84%
# ... starting validation
# ... epoch 97: validation accuracy 51.19%
# ... starting validation
# ... epoch 98: validation accuracy 53.68%
# ... starting validation
# ... epoch 99: validation accuracy 53.03%
# ... starting validation
# ... epoch 100: validation accuracy 51.34%
# ... starting validation
# ... epoch 101: validation accuracy 53.03%
# ... starting validation
# ... epoch 102: validation accuracy 54.53%
# ... starting validation
# ... epoch 103: validation accuracy 53.23%
# ... starting validation
# ... epoch 104: validation accuracy 52.64%
# ... starting validation
# ... epoch 105: validation accuracy 53.33%
# ... starting validation
# ... epoch 106: validation accuracy 54.28%
# ... starting validation
# ... epoch 107: validation accuracy 54.53%
# ... starting validation
# ... epoch 108: validation accuracy 53.83%
# ... starting validation
# ... epoch 109: validation accuracy 51.64%
# ... starting validation
# ... epoch 110: validation accuracy 51.74%
# ... starting validation
# ... epoch 111: validation accuracy 46.72%
# ... starting validation
# ... epoch 112: validation accuracy 52.99%
# ... starting validation
# ... epoch 113: validation accuracy 54.33%
# ... starting validation
# ... epoch 114: validation accuracy 55.92%
# ... this is the best validation accuracy to date.
# ... the corresponding test accuracy is 54.33%
# ... starting validation
# ... epoch 115: validation accuracy 55.87%
# ... starting validation
# ... epoch 116: validation accuracy 53.13%
# ... starting validation
# ... epoch 117: validation accuracy 53.23%
# ... starting validation
# ... epoch 118: validation accuracy 52.84%
# ... starting validation
# ... epoch 119: validation accuracy 51.44%
# ... starting validation
# ... epoch 120: validation accuracy 54.08%
# ... starting validation
# ... epoch 121: validation accuracy 55.67%
# ... starting validation
# ... epoch 122: validation accuracy 52.19%
# ... starting validation
# ... epoch 123: validation accuracy 38.91%
# ... starting validation
# ... epoch 124: validation accuracy 46.82%
# ... starting validation
# ... epoch 125: validation accuracy 53.58%
# ... starting validation
# ... epoch 126: validation accuracy 53.03%
# ... starting validation
# ... epoch 127: validation accuracy 51.04%
# ... starting validation
# ... epoch 128: validation accuracy 30.15%
# ... starting validation
# ... epoch 129: validation accuracy 48.21%
# ... starting validation
# ... epoch 130: validation accuracy 51.14%
# ... starting validation
# ... epoch 131: validation accuracy 52.64%
# ... starting validation
# ... epoch 132: validation accuracy 51.89%
# ... starting validation
# ... epoch 133: validation accuracy 51.89%
# ... starting validation
# ... epoch 134: validation accuracy 53.58%
# ... starting validation
# ... epoch 135: validation accuracy 54.28%
# ... starting validation
# ... epoch 136: validation accuracy 51.89%
# ... starting validation
# ... epoch 137: validation accuracy 53.48%
# ... starting validation
# ... epoch 138: validation accuracy 52.34%
# ... starting validation
# ... epoch 139: validation accuracy 49.60%
# ... starting validation
# ... epoch 140: validation accuracy 51.49%
# ... starting validation
# ... epoch 141: validation accuracy 54.48%
# ... starting validation
# ... epoch 142: validation accuracy 51.99%
# ... starting validation
# ... epoch 143: validation accuracy 54.18%
# ... starting validation
# ... epoch 144: validation accuracy 53.63%
# ... starting validation
# ... epoch 145: validation accuracy 51.04%
# ... starting validation
# ... epoch 146: validation accuracy 50.75%
# ... starting validation
# ... epoch 147: validation accuracy 31.09%
# ... starting validation
# ... epoch 148: validation accuracy 52.79%
# ... starting validation
# ... epoch 149: validation accuracy 52.59%
# ... starting validation
# ... epoch 150: validation accuracy 52.99%
# ... starting validation
# ... epoch 151: validation accuracy 54.78%
# ... starting validation
# ... epoch 152: validation accuracy 54.98%
# ... starting validation
# ... epoch 153: validation accuracy 52.59%
# ... starting validation
# ... epoch 154: validation accuracy 52.29%
# ... starting validation
# ... epoch 155: validation accuracy 47.21%
# ... starting validation
# ... epoch 156: validation accuracy 45.22%
# ... starting validation
# ... epoch 157: validation accuracy 49.70%
# ... starting validation
# ... epoch 158: validation accuracy 52.99%
# ... starting validation
# ... epoch 159: validation accuracy 49.40%
# ... starting validation
# ... epoch 160: validation accuracy 39.60%
# ... starting validation
# ... epoch 161: validation accuracy 37.31%
# ... starting validation
# ... epoch 162: validation accuracy 40.45%
# ... starting validation
# ... epoch 163: validation accuracy 28.86%
# ... starting validation
# ... epoch 164: validation accuracy 28.36%
# ... starting validation
# ... epoch 165: validation accuracy 36.82%
# ... starting validation
# ... epoch 166: validation accuracy 24.93%
# ... starting validation
# ... epoch 167: validation accuracy 12.74%
# ... starting validation
# ... epoch 168: validation accuracy 29.40%
# ... starting validation
# ... epoch 169: validation accuracy 30.45%
# ... starting validation
# ... epoch 170: validation accuracy 40.45%
# ... starting validation
# ... epoch 171: validation accuracy 28.76%
# ... starting validation
# ... epoch 172: validation accuracy 44.43%
# ... starting validation
# ... epoch 173: validation accuracy 45.12%
# ... starting validation
# ... epoch 174: validation accuracy 30.05%
# ... starting validation
# ... epoch 175: validation accuracy 12.74%
# ... starting validation
# ... epoch 176: validation accuracy 12.74%
# ... starting validation
# ... epoch 177: validation accuracy 12.74%
# ... starting validation
# ... epoch 178: validation accuracy 29.55%
# ... starting validation
# ... epoch 179: validation accuracy 30.40%
# ... starting validation
# ... epoch 180: validation accuracy 46.07%
# ... starting validation
# ... epoch 181: validation accuracy 29.15%
# ... starting validation
# ... epoch 182: validation accuracy 33.53%
# ... starting validation
# ... epoch 183: validation accuracy 33.38%
# ... starting validation
# ... epoch 184: validation accuracy 31.04%
# ... starting validation
# ... epoch 185: validation accuracy 12.74%
# ... starting validation
# ... epoch 186: validation accuracy 12.74%
# ... starting validation
# ... epoch 187: validation accuracy 13.53%
# ... starting validation
# ... epoch 188: validation accuracy 12.74%
# ... starting validation
# ... epoch 189: validation accuracy 12.74%
# ... starting validation
# ... epoch 190: validation accuracy 22.94%
# ... starting validation
# ... epoch 191: validation accuracy 31.44%
# ... starting validation
# ... epoch 192: validation accuracy 15.02%
# ... starting validation
# ... epoch 193: validation accuracy 15.02%
# ... starting validation
# ... epoch 194: validation accuracy 15.02%
# ... starting validation
# ... epoch 195: validation accuracy 15.02%
# ... starting validation
# ... epoch 196: validation accuracy 15.02%
# ... starting validation
# ... epoch 197: validation accuracy 15.02%
# ... starting validation
# ... epoch 198: validation accuracy 15.02%
# ... starting validation
# ... epoch 199: validation accuracy 15.02%
# ... starting validation
# ... epoch 200: validation accuracy 15.02%
# ... starting validation
# ... epoch 201: validation accuracy 15.02%
# ... starting validation
# ... epoch 202: validation accuracy 15.02%
# ... starting validation
# ... epoch 203: validation accuracy 15.02%
# ... starting validation
# ... epoch 204: validation accuracy 15.02%
# ... starting validation
# ... epoch 205: validation accuracy 15.02%
# ... starting validation
# ... epoch 206: validation accuracy 15.02%
# ... starting validation
# ... epoch 207: validation accuracy 15.02%
# ... starting validation
# ... epoch 208: validation accuracy 15.02%
# ... starting validation
# ... epoch 209: validation accuracy 15.02%
# ... starting validation
# ... epoch 210: validation accuracy 15.02%
# ... starting validation
# ... epoch 211: validation accuracy 15.02%
# ... starting validation
# ... epoch 212: validation accuracy 15.02%
# ... starting validation
# ... epoch 213: validation accuracy 15.02%
# ... starting validation
# ... epoch 214: validation accuracy 15.02%
# ... starting validation
# ... epoch 215: validation accuracy 15.02%
# ... starting validation
# ... epoch 216: validation accuracy 15.02%
# ... starting validation
# ... epoch 217: validation accuracy 15.02%
# ... starting validation
# ... epoch 218: validation accuracy 15.02%
# ... starting validation
# ... epoch 219: validation accuracy 15.02%
# ... starting validation
# ... epoch 220: validation accuracy 15.02%
# ... starting validation
# ... epoch 221: validation accuracy 15.02%
# ... starting validation
# ... epoch 222: validation accuracy 15.02%
# ... starting validation
# ... epoch 223: validation accuracy 15.02%
# ... starting validation
# ... epoch 224: validation accuracy 15.02%
# ... starting validation
# ... epoch 225: validation accuracy 15.02%
# ... starting validation
# ... epoch 226: validation accuracy 15.02%
# ... starting validation
# ... epoch 227: validation accuracy 15.02%
# ... starting validation
# ... epoch 228: validation accuracy 15.02%
# ... starting validation
# ... epoch 229: validation accuracy 15.02%
# ... starting validation
# ... epoch 230: validation accuracy 15.02%
# ... starting validation
# ... epoch 231: validation accuracy 15.02%
# ... starting validation
# ... epoch 232: validation accuracy 15.02%
# ... starting validation
# ... epoch 233: validation accuracy 15.02%
# ... starting validation
# ... epoch 234: validation accuracy 15.02%
# ... starting validation
# ... epoch 235: validation accuracy 15.02%
# ... starting validation
# ... epoch 236: validation accuracy 15.02%
# ... starting validation
# ... epoch 237: validation accuracy 15.02%
# ... starting validation
# ... epoch 238: validation accuracy 21.14%
# ... starting validation
# ... epoch 239: validation accuracy 26.57%
# ... starting validation
# ... epoch 240: validation accuracy 15.02%
# ... starting validation
# ... epoch 241: validation accuracy 15.02%
# ... starting validation
# ... epoch 242: validation accuracy 15.02%
# ... starting validation
# ... epoch 243: validation accuracy 15.02%
# ... starting validation
# ... epoch 244: validation accuracy 15.02%
# ... starting validation
# ... epoch 245: validation accuracy 15.02%
# ... starting validation
# ... epoch 246: validation accuracy 15.02%
# ... starting validation
# ... epoch 247: validation accuracy 15.02%
# ... starting validation
# ... epoch 248: validation accuracy 16.32%
# ... starting validation
# ... epoch 249: validation accuracy 19.15%
# ... starting validation
# ... epoch 250: validation accuracy 21.34%
# ... starting validation
# ... epoch 251: validation accuracy 22.29%
# ... starting validation
# ... epoch 252: validation accuracy 24.28%
# ... starting validation
# ... epoch 253: validation accuracy 23.08%
# ... starting validation
# ... epoch 254: validation accuracy 23.43%
# ... starting validation
# ... epoch 255: validation accuracy 23.28%
# ... starting validation
# ... epoch 256: validation accuracy 15.02%
# ... starting validation
# ... epoch 257: validation accuracy 31.24%
# ... starting validation
# ... epoch 258: validation accuracy 12.04%
# ... starting validation
# ... epoch 259: validation accuracy 26.82%
# ... starting validation
# ... epoch 260: validation accuracy 24.83%
# ... starting validation
# ... epoch 261: validation accuracy 28.11%
# ... starting validation
# ... epoch 262: validation accuracy 28.76%
# ... starting validation
# ... epoch 263: validation accuracy 19.50%
# ... starting validation
# ... epoch 264: validation accuracy 28.76%
# ... starting validation
# ... epoch 265: validation accuracy 18.16%
# ... starting validation
# ... epoch 266: validation accuracy 30.80%
# ... starting validation
# ... epoch 267: validation accuracy 30.05%
# ... starting validation
# ... epoch 268: validation accuracy 30.65%
# ... starting validation
# ... epoch 269: validation accuracy 23.18%
# ... starting validation
# ... epoch 270: validation accuracy 24.03%
# ... starting validation
# ... epoch 271: validation accuracy 24.13%
# ... starting validation
# ... epoch 272: validation accuracy 24.23%
# ... starting validation
# ... epoch 273: validation accuracy 13.53%
# ... starting validation
# ... epoch 274: validation accuracy 12.74%
# ... starting validation
# ... epoch 275: validation accuracy 13.53%
# ... starting validation
# ... epoch 276: validation accuracy 12.74%
# ... starting validation
# ... epoch 277: validation accuracy 27.21%
# ... starting validation
# ... epoch 278: validation accuracy 29.95%
# ... starting validation
# ... epoch 279: validation accuracy 28.96%
# ... starting validation
# ... epoch 280: validation accuracy 30.50%
# ... starting validation
# ... epoch 281: validation accuracy 27.16%
# ... starting validation
# ... epoch 282: validation accuracy 27.56%
# ... starting validation
# ... epoch 283: validation accuracy 27.46%
# ... starting validation
# ... epoch 284: validation accuracy 29.90%
# ... starting validation
# ... epoch 285: validation accuracy 26.12%
# ... starting validation
# ... epoch 286: validation accuracy 13.53%
# ... starting validation
# ... epoch 287: validation accuracy 12.74%
# ... starting validation
# ... epoch 288: validation accuracy 13.48%
# ... starting validation
# ... epoch 289: validation accuracy 20.90%
# ... starting validation
# ... epoch 290: validation accuracy 24.08%
# ... starting validation
# ... epoch 291: validation accuracy 28.66%
# ... starting validation
# ... epoch 292: validation accuracy 15.02%
# ... starting validation
# ... epoch 293: validation accuracy 21.59%
# ... starting validation
# ... epoch 294: validation accuracy 15.02%
# ... starting validation
# ... epoch 295: validation accuracy 12.74%
# ... starting validation
# ... epoch 296: validation accuracy 12.74%
# ... starting validation
# ... epoch 297: validation accuracy 15.02%
# ... starting validation
# ... epoch 298: validation accuracy 15.02%
# ... starting validation
# ... epoch 299: validation accuracy 15.02%
# ... starting validation
# ... epoch 300: validation accuracy 15.02%
# ... starting validation
# ... epoch 301: validation accuracy 15.02%
# ... starting validation
# ... epoch 302: validation accuracy 15.02%
# ... starting validation
# ... epoch 303: validation accuracy 15.02%
# ... starting validation
# ... epoch 304: validation accuracy 15.02%
# ... starting validation
# ... epoch 305: validation accuracy 15.02%
# ... starting validation
# ... epoch 306: validation accuracy 15.02%
# ... starting validation
# ... epoch 307: validation accuracy 15.02%
# ... starting validation
# ... epoch 308: validation accuracy 15.02%
# ... starting validation
# ... epoch 309: validation accuracy 15.02%
# ... starting validation
# ... epoch 310: validation accuracy 15.02%
# ... starting validation
# ... epoch 311: validation accuracy 15.02%
# ... starting validation
# ... epoch 312: validation accuracy 15.02%
# ... starting validation
# ... epoch 313: validation accuracy 15.02%
# ... starting validation
# ... epoch 314: validation accuracy 15.02%
# ... starting validation
# ... epoch 315: validation accuracy 15.02%
# ... starting validation
# ... epoch 316: validation accuracy 15.02%
# ... starting validation
# ... epoch 317: validation accuracy 15.02%
# ... starting validation
# ... epoch 318: validation accuracy 15.02%
# ... starting validation
# ... epoch 319: validation accuracy 15.02%
# ... starting validation
# ... epoch 320: validation accuracy 15.02%
# ... starting validation
# ... epoch 321: validation accuracy 15.02%
# ... starting validation
# ... epoch 322: validation accuracy 15.02%
# ... starting validation
# ... epoch 323: validation accuracy 15.02%
# ... starting validation
# ... epoch 324: validation accuracy 15.02%
# ... starting validation
# ... epoch 325: validation accuracy 15.02%
# ... starting validation
# ... epoch 326: validation accuracy 15.02%
# ... starting validation
# ... epoch 327: validation accuracy 15.02%
# ... starting validation
# ... epoch 328: validation accuracy 15.02%
# ... starting validation
# ... epoch 329: validation accuracy 15.02%
# ... starting validation
# ... epoch 330: validation accuracy 15.02%
# ... starting validation
# ... epoch 331: validation accuracy 15.02%
# ... starting validation
# ... epoch 332: validation accuracy 15.02%
# ... starting validation
# ... epoch 333: validation accuracy 15.02%
# ... starting validation
# ... epoch 334: validation accuracy 15.02%
# ... starting validation
# ... epoch 335: validation accuracy 15.02%
# ... starting validation
# ... epoch 336: validation accuracy 15.02%
# ... starting validation
# ... epoch 337: validation accuracy 15.02%
# ... starting validation
# ... epoch 338: validation accuracy 15.02%
# ... starting validation
# ... epoch 339: validation accuracy 15.02%
# ... starting validation
# ... epoch 340: validation accuracy 15.02%
# ... starting validation
# ... epoch 341: validation accuracy 15.02%
# ... starting validation
# ... epoch 342: validation accuracy 15.02%
# ... starting validation
# ... epoch 343: validation accuracy 15.02%
# ... starting validation
# ... epoch 344: validation accuracy 15.02%
# ... starting validation
# ... epoch 345: validation accuracy 15.02%
# ... starting validation
# ... epoch 346: validation accuracy 15.02%
# ... starting validation
# ... epoch 347: validation accuracy 15.02%
# ... starting validation
# ... epoch 348: validation accuracy 15.02%
# ... starting validation
# ... epoch 349: validation accuracy 15.02%
# ... starting validation
# ... epoch 350: validation accuracy 15.02%
# ... starting validation
# ... epoch 351: validation accuracy 15.02%
# ... starting validation
# ... epoch 352: validation accuracy 15.02%
# ... starting validation
# ... epoch 353: validation accuracy 15.02%
# ... starting validation
# ... epoch 354: validation accuracy 15.02%
# ... starting validation
# ... epoch 355: validation accuracy 15.02%
# ... starting validation
# ... epoch 356: validation accuracy 15.02%
# ... starting validation
# ... epoch 357: validation accuracy 15.02%
# ... starting validation
# ... epoch 358: validation accuracy 15.02%
# ... starting validation
# ... epoch 359: validation accuracy 15.02%
# ... starting validation
# ... epoch 360: validation accuracy 15.02%
# ... starting validation
# ... epoch 361: validation accuracy 15.02%
# ... starting validation
# ... epoch 362: validation accuracy 15.02%
# ... starting validation
# ... epoch 363: validation accuracy 15.02%
# ... starting validation
# ... epoch 364: validation accuracy 15.02%
# ... starting validation
# ... epoch 365: validation accuracy 15.02%
# ... starting validation
# ... epoch 366: validation accuracy 15.02%
# ... starting validation
# ... epoch 367: validation accuracy 15.02%
# ... starting validation
# ... epoch 368: validation accuracy 15.02%
# ... starting validation
# ... epoch 369: validation accuracy 15.02%
# ... starting validation
# ... epoch 370: validation accuracy 15.02%
# ... starting validation
# ... epoch 371: validation accuracy 15.02%
# ... starting validation
# ... epoch 372: validation accuracy 15.02%
# ... starting validation
# ... epoch 373: validation accuracy 15.02%
# ... starting validation
# ... epoch 374: validation accuracy 15.02%
# ... starting validation
# ... epoch 375: validation accuracy 15.02%
# ... starting validation
# ... epoch 376: validation accuracy 15.02%
# ... starting validation
# ... epoch 377: validation accuracy 15.02%
# ... starting validation
# ... epoch 378: validation accuracy 15.02%
# ... starting validation
# ... epoch 379: validation accuracy 15.02%
# ... starting validation
# ... epoch 380: validation accuracy 15.02%
# ... starting validation
# ... epoch 381: validation accuracy 15.02%
# ... starting validation
# ... epoch 382: validation accuracy 15.02%
# ... starting validation
# ... epoch 383: validation accuracy 15.02%
# ... starting validation
# ... epoch 384: validation accuracy 15.02%
# ... starting validation
# ... epoch 385: validation accuracy 15.02%
# ... starting validation
# ... epoch 386: validation accuracy 15.02%
# ... starting validation
# ... epoch 387: validation accuracy 15.02%
# ... starting validation
# ... epoch 388: validation accuracy 15.02%
# ... starting validation
# ... epoch 389: validation accuracy 15.02%
# ... starting validation
# ... epoch 390: validation accuracy 15.02%
# ... starting validation
# ... epoch 391: validation accuracy 15.02%
# ... starting validation
# ... epoch 392: validation accuracy 15.02%
# ... starting validation
# ... epoch 393: validation accuracy 15.02%
# ... starting validation
# ... epoch 394: validation accuracy 15.02%
# ... starting validation
# ... epoch 395: validation accuracy 15.02%
# ... starting validation
# ... epoch 396: validation accuracy 15.02%
# ... starting validation
# ... epoch 397: validation accuracy 15.02%
# ... starting validation
# ... epoch 398: validation accuracy 15.02%
# ... starting validation
# ... epoch 399: validation accuracy 15.02%
# ... finished training network.
# ... best validation accuracy of 55.92% obtained at iteration 46344
# ... corresponding test accuracy of 54.33%
